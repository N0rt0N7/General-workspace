# %%
import numpy as np
import matplotlib.pyplot as plt
import pylab as plb
import scipy
from scipy.optimize import curve_fit
from numpy import asarray as ar,exp

y3 = []
y7 = []
y11 = []
y15 = []
y19 = []
y23 = []
y27 = []

def read_file_with_skipped_lines3(file_path, num_lines_to_skip_first, num_lines_to_skip_last):
    with open(file_path3, 'r') as file:
        lines = file.readlines()
        # Skip the first x lines
        lines = lines[num_lines_to_skip_first:]
        # Skip the last y lines
        lines = lines[:-num_lines_to_skip_last]
        for line in lines:
            y3.append(int(line.strip()))  # Process the remaining lines
            
def read_file_with_skipped_lines7(file_path, num_lines_to_skip_first, num_lines_to_skip_last):
    with open(file_path7, 'r') as file:
        lines = file.readlines()
        # Skip the first x lines
        lines = lines[num_lines_to_skip_first:]
        # Skip the last y lines
        lines = lines[:-num_lines_to_skip_last]
        for line in lines:
            y7.append(int(line.strip()))  # Process the remaining lines
            
def read_file_with_skipped_lines11(file_path, num_lines_to_skip_first, num_lines_to_skip_last):
    with open(file_path11, 'r') as file:
        lines = file.readlines()
        # Skip the first x lines
        lines = lines[num_lines_to_skip_first:]
        # Skip the last y lines
        lines = lines[:-num_lines_to_skip_last]
        for line in lines:
            y11.append(int(line.strip()))  # Process the remaining lines
            
def read_file_with_skipped_lines15(file_path, num_lines_to_skip_first, num_lines_to_skip_last):
    with open(file_path15, 'r') as file:
        lines = file.readlines()
        # Skip the first x lines
        lines = lines[num_lines_to_skip_first:]
        # Skip the last y lines
        lines = lines[:-num_lines_to_skip_last]
        for line in lines:
            y15.append(int(line.strip()))  # Process the remaining lines
            

def read_file_with_skipped_lines19(file_path, num_lines_to_skip_first, num_lines_to_skip_last):
    with open(file_path19, 'r') as file:
        lines = file.readlines()
        # Skip the first x lines
        lines = lines[num_lines_to_skip_first:]
        # Skip the last y lines
        lines = lines[:-num_lines_to_skip_last]
        for line in lines:
            y19.append(int(line.strip()))  # Process the remaining lines
            

def read_file_with_skipped_lines23(file_path, num_lines_to_skip_first, num_lines_to_skip_last):
    with open(file_path23, 'r') as file:
        lines = file.readlines()
        # Skip the first x lines
        lines = lines[num_lines_to_skip_first:]
        # Skip the last y lines
        lines = lines[:-num_lines_to_skip_last]
        for line in lines:
            y23.append(int(line.strip()))  # Process the remaining lines
            

def read_file_with_skipped_lines27(file_path, num_lines_to_skip_first, num_lines_to_skip_last):
    with open(file_path27, 'r') as file:
        lines = file.readlines()
        # Skip the first x lines
        lines = lines[num_lines_to_skip_first:]
        # Skip the last y lines
        lines = lines[:-num_lines_to_skip_last]
        for line in lines:
            y27.append(int(line.strip()))  # Process the remaining lines
            

x = list(range(1, 4095))
    
file_path3 = "task1-3mm.txt" 
num_lines_to_skip_first = 13
num_lines_to_skip_last = 15
read_file_with_skipped_lines3(file_path3, num_lines_to_skip_first, num_lines_to_skip_last)

file_path7 = "task1-7mm.txt" 
num_lines_to_skip_first = 13
num_lines_to_skip_last = 15
read_file_with_skipped_lines7(file_path7, num_lines_to_skip_first, num_lines_to_skip_last)

file_path11 = "task1-11mm.txt" 
num_lines_to_skip_first = 13
num_lines_to_skip_last = 15
read_file_with_skipped_lines11(file_path11, num_lines_to_skip_first, num_lines_to_skip_last)

file_path15 = "task1-15mm.txt" 
num_lines_to_skip_first = 13
num_lines_to_skip_last = 15
read_file_with_skipped_lines15(file_path15, num_lines_to_skip_first, num_lines_to_skip_last)

file_path19 = "task1-19mm.txt" 
num_lines_to_skip_first = 13
num_lines_to_skip_last = 15
read_file_with_skipped_lines19(file_path19, num_lines_to_skip_first, num_lines_to_skip_last)

file_path23 = "task1-23mm.txt" 
num_lines_to_skip_first = 13
num_lines_to_skip_last = 15
read_file_with_skipped_lines23(file_path23, num_lines_to_skip_first, num_lines_to_skip_last)

file_path27 = "task1-27mm.txt" 
num_lines_to_skip_first = 13
num_lines_to_skip_last = 15
read_file_with_skipped_lines27(file_path27, num_lines_to_skip_first, num_lines_to_skip_last)

y3_max = max(y3)
y7_max = max(y7)
y11_max = max(y11)
y15_max = max(y15)
y19_max = max(y19)
y23_max = max(y23)
y27_max = max(y27)

print("Peak at 3: ",y3_max)
print("Peak at 7: ",y7_max)
print("Peak at 11: ",y11_max)
print("Peak at 15: ",y15_max)
print("Peak at 19: ",y19_max)
print("Peak at 23: ",y23_max)
print("Peak at 27: ",y27_max)

#print("Peak at: ",y_max)

index_y_max = y3.index(y3_max)

plt.axvline(x=index_y_max, color='red', linestyle='-.')
plt.xlim([3220, 3300])
plt.plot(x, np.divide(y3, 1471))
plt.plot(x, np.divide(y7, 1233))
plt.plot(x, np.divide(y11, 904))
plt.plot(x, np.divide(y15, 688))
plt.plot(x, np.divide(y19, 513))
plt.plot(x, np.divide(y23, 381))
plt.plot(x, np.divide(y27, 312))
plt.xlabel('Energy (keV)')
plt.ylabel('Intencity (a.u.)') 
plt.title('3 - 27 mm Normalised plot')
plt.grid(True)
plt.show()
# Out:
# Peak at 3:  1471
# Peak at 7:  1233
# Peak at 11:  904
# Peak at 15:  688
# Peak at 19:  513
# Peak at 23:  381
# Peak at 27:  312

# %%
import numpy as np
import matplotlib.pyplot as plt
import pylab as plb
import scipy
import statistics
from scipy.optimize import curve_fit
from numpy import asarray as ar,exp

y3 = []

def read_file_with_skipped_lines3(file_path, num_lines_to_skip_first, num_lines_to_skip_last):
    with open(file_path3, 'r') as file:
        lines = file.readlines()
        # Skip the first x lines
        lines = lines[num_lines_to_skip_first:]
        # Skip the last y lines
        lines = lines[:-num_lines_to_skip_last]
        for line in lines:
            y3.append(int(line.strip()))  # Process the remaining lines
            
x = list(range(1, 4097))



x = list(map(int, x))    
y3 = list(map(int, y3)) 

file_path3 = "task1-3mm.txt" 
num_lines_to_skip_first = 12
num_lines_to_skip_last = 14
read_file_with_skipped_lines3(file_path3, num_lines_to_skip_first, num_lines_to_skip_last)

y_max = max(y3)
print("Peak at 3mm: ",y_max)

index_y_max = y3.index(y_max)

n = len(x)                          #the number of data
mean = statistics.fmean(x, y3)/n  
g = [x - mean for x in x]                 
sigma = sum(y3* (g)**2)/n        #note this correction

def gaus(x,a,x0,sigma):
    return a*exp(-(x-x0)**2/(2*sigma**2))

popt,pcov = curve_fit(gaus,x,y,p0=[1,mean,sigma])


print(x)
print(y3)
print(len(x))
print(len(y3))

plt.axvline(x=index_y_max, color='red', linestyle='-.')
plt.xlim([2800, 3500])
plt.plot(x, y3)
plt.plot(x, gaus(x, *popt), '-', label='Fitted Gaussian')
plt.xlabel('Energy (keV)')
plt.ylabel('Intencity (a.u.)') 
plt.title('7mm')
plt.grid(True)
plt.show()
# Out:
# Peak at 3mm:  1471
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 41
#      39 mean = statistics.fmean(x, y3)/n
#      40 g = [x - mean for x in x]
# ---> 41 sigma = sum(y3* (g)**2)/n        #note this correction
#      43 def gaus(x,a,x0,sigma):
#      44     return a*exp(-(x-x0)**2/(2*sigma**2))
#
# TypeError: unsupported operand type(s) for ** or pow(): 'list' and 'int'
