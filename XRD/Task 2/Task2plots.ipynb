# %%
import pandas as pd
from matplotlib import pyplot as plt
import plotly.express as px
  
plt.figure(figsize=(12,4))

df = pd.read_csv('ZnO-a-plane.csv', skiprows=21)
x = df['Angle']
y = df['Intensity']

#peak_list = [28.420, 47.306, 56.103, 69.173, 76.372, 88.059, 94.975, 106.735, 114.130, 127.574, 136.933]
#peak_orientation = ['(111)', '(220)', '(311)', '(400)', '(331)', '(422)', '(511)', '(440)', '(531)', '(620)', '(533)']

plt.xlim([30, 130])
plt.yscale('log')

plt.xlabel('2θ Angle')
plt.ylabel('Intensity')

#peak_list_ZnO = [ 34.44,  72.61,  81.405, 125.234]
#peak_orientation_ZnO = [ '(002)', '(004)', '(104)', '(006)']

#for position in peak_list_ZnO:
    #plt.axvline(x=position, color='red', linestyle='-.', label=f'X={position}')
    #orient = peak_list_ZnO.index(position)
    #plt.text(position, 1.8, f'{peak_orientation_ZnO[orient]}', color='black', fontsize=8, ha='right', bbox=dict(facecolor='white', edgecolor='red', boxstyle='square,pad=0.2'))

#peak_list_Al2O3 = [ 35.142, 37.763, 74.282, 80.666]
#peak_orientation_Al2O3 = [ '(104)', '(110)', '(208)', '(220)']

#for position in peak_list_Al2O3:
    #plt.axvline(x=position, color='green', linestyle='--', label=f'X={position}')
    #orient = peak_list_Al2O3.index(position)
    #plt.text(position, 0.8, f'{peak_orientation_Al2O3[orient]}', color='black', fontsize=8, ha='left', bbox=dict(facecolor='white', edgecolor='green', boxstyle='square,pad=0.2'))

df = pd.read_csv('1000017 - Al2O3 Bragg peaks.csv', skiprows=0)

# Convert the numeric columns to strings and concatenate them
df['hkl'] = df['h'].astype(str) + df['k'].astype(str) + df['l'].astype(str)
df['2t'] = df['2theta']

hkl = ['hkl']
twotheta = df['2t']

for position in twotheta:
    plt.axvline(x=position, color='red', linestyle='-.', label=f'X={position}')
    orient = twotheta.index(position)
    plt.text(position, 1.8, f'{hkl[orient]}', color='black', fontsize=8, ha='right', bbox=dict(facecolor='white', edgecolor='red', boxstyle='square,pad=0.2'))

plt.title('XRD of ZnO (a-plane)')
plt.grid(True) 
plt.plot(x,y,linewidth=0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 48
#      46     plt.axvline(x=position, color='red', linestyle='-.', label=f'X={position}')
#      47     #orient = twotheta.index(position)
# ---> 48     plt.text(position, 1.8, f'{hkl[orient]}', color='black', fontsize=8, ha='right', bbox=dict(facecolor='white', edgecolor='red', boxstyle='square,pad=0.2'))
#      50 plt.title('XRD of ZnO (a-plane)')
#      51 plt.grid(True)
#
# NameError: name 'orient' is not defined

# %%
import pandas as pd
from matplotlib import pyplot as plt
import plotly.express as px
  
plt.figure(figsize=(12,4))

df = pd.read_csv('ZnO-r-plane.csv', skiprows=21)
x = df['Angle']
y = df['Intensity']

plt.xlim([20, 130])
plt.yscale('log')

plt.xlabel('2θ Angle')
plt.ylabel('Intensity')

peak_list_ZnO = [47.543, 56.555, 81.405, 125.234]
peak_orientation_ZnO = ['(102)','(110)','(104)','(006)']

for position in peak_list_ZnO:
    plt.axvline(x=position, color='red', linestyle='--', label=f'X={position}')
    orient = peak_list_ZnO.index(position)
    plt.text(position, 1.8, f'{peak_orientation_ZnO[orient]}', color='black', fontsize=8, ha='right', bbox=dict(facecolor='white', edgecolor='red', boxstyle='square,pad=0.2'))

peak_list_Al2O3 = [ 25.569, 37.763, 46.163, 52.535, 68.183]
peak_orientation_Al2O3 = [ '(012)', '(110)', '(202)','(024)', '(300)']

#peak_list_Al2O3 = [ 25.569, 35.142, 37.763, 43.34, 46.163, 52.535, 57.485, 59.718, 61.108, 61.291, 66.495, 68.183, 74.282, 80.666, 84.323, 85.104, 86.316]
#peak_orientation_Al2O3 = [ '(012)', '(104)', '(110)', '(113)', '(202)', '(024)', '(116)', '(211)', '(122)', '(018)', '(214)', '(300)', '(208)', '(220)', '(223)', '(131)', '(312)']

for position in peak_list_Al2O3:
    plt.axvline(x=position, color='green', linestyle='--', label=f'X={position}')
    orient = peak_list_Al2O3.index(position)
    plt.text(position, 0.8, f'{peak_orientation_Al2O3[orient]}', color='black', fontsize=8, ha='left', bbox=dict(facecolor='white', edgecolor='green', boxstyle='square,pad=0.2'))    

plt.title('XRD of ZnO (r-plane)')
plt.grid(True) 
plt.plot(x,y,linewidth=0.5)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
peak_list_ZnO = [31.751, 34.44, 36.252, 47.543, 56.555, 62.87, 66.388, 67.917, 69.057, 72.61, 76.956, 81.405, 89.63, 92.777, 95.311, 98.632, 102.923, 104.169, 107.448, 110.378, 116.288, 121.562, 125.234, 133.975, 136.618, 138.511, 142.905]
peak_orientation_ZnO = ['(100)','(002)','(101)','(102)','(110)','(103)','(200)','(112)','(201)','(004)','(202)','(104)','(203)','(210)','(211)','(114)','(212)','(105)','(204)','(300)','(213)','(302)','(006)','(205)','(106)','(214)','(220)']

peak_list_Al2O3 = [ 25.569, 35.142, 37.763, 43.34, 46.163, 52.535, 57.485, 59.718, 61.108, 61.291, 66.495, 68.183, 74.282, 80.666, 84.323, 85.104, 86.316]
peak_orientation_Al2O3 = [ '(012)', '(104)', '(110)', '(113)', '(202)', '(024)', '(116)', '(211)', '(122)', '(018)', '(214)', '(300)', '(208)', '(220)', '(223)', '(131)', '(312)']

# %%
import pandas as pd

df = pd.read_csv('1000017 - Al2O3 Bragg peaks.csv')

# Convert the numeric columns to strings and concatenate them
df['hkl'] = df['h'].astype(str) + df['k'].astype(str) + df['l'].astype(str)
df['2t'] = df['2theta']

print(df['hkl'])
print(df['2theta'])
# Out:
# 0      012
# 1      012
# 2      104
# 3      104
# 4      110
#       ...
# 91     143
# 92     048
# 93     048
# 94    1310
# 95    1310
# Name: hkl, Length: 96, dtype: object
# 0     58.91378
# 1     29.30763
# 2     94.29299
# 3     46.89655
# 4     44.27761
#         ...
# 91     1.71017
# 92     4.33186
# 93     2.18941
# 94    25.15502
# 95    12.73581
# Name: 2theta, Length: 96, dtype: float64

# %%
import pandas as pd
from matplotlib import pyplot as plt
import plotly.express as px

plt.figure(figsize=(12,4))

# Load the CSV file into a DataFrame
df = pd.read_csv('1000017 - Al2O3 Bragg peaks.csv', skiprows=0)

# Sort by the 'value' column in ascending order and reset the index
df_sorted = df.sort_values(by='2theta',ascending=True).reset_index(drop=True)

# Print the sorted DataFrame
#print(df_sorted)

df['hkl'] = df['h'].astype(str) + df['k'].astype(str) + df['l'].astype(str)
hkl = df['hkl'] 

print(hkl + ' ' +df['2theta'].astype(str))
# Out:
# 0         012 25.5686
# 1        012 25.63158
# 2        104 35.14203
# 3        104 35.22992
# 4        110 37.76315
#             ...
# 111    3111 140.04867
# 112     502 140.67272
# 113     238 140.92705
# 114     502 141.45689
# 115     238 141.71685
# Length: 116, dtype: object
