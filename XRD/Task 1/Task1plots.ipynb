# %%
import pandas as pd
from matplotlib import pyplot as plt
import plotly.express as px
  
plt.figure(figsize=(10,3))

df = pd.read_csv('Si-Task 1.csv', skiprows=21)
x = df['Angle']
y = df['Intensity']

peak_list = [28.420, 47.306, 56.103, 69.173, 76.372, 88.059, 94.975, 106.735, 114.130, 127.574, 136.933]
peak_orientation = ['(111)', '(220)', '(311)', '(400)', '(331)', '(422)', '(511)', '(440)', '(531)', '(620)', '(533)']

plt.xlim([20, 140])
plt.yscale('log')

plt.xlabel('2θ Angle')
plt.ylabel('Intensity')

for position in peak_list:
    plt.axvline(x=position, color='red', linestyle='--', label=f'X={position}')
    orient = peak_list.index(position)
    plt.text(position, 0.8, f'{peak_orientation[orient]}', color='black', fontsize=9, ha='center', bbox=dict(facecolor='white', edgecolor='black', boxstyle='square,pad=0.2'))

plt.grid(True) 
plt.plot(x,y,linewidth=0.5)

# %%
import pandas as pd
from matplotlib import pyplot as plt
import plotly.express as px

plt.figure(figsize=(10,3))

df = pd.read_csv('ZnO_Task1.csv', skiprows=21)
x = df['Angle']
y = df['Intensity']

peak_list = [31.751, 34.44, 36.252, 47.543, 56.555, 62.87, 66.388, 67.917, 69.057, 72.61, 76.956]
peak_orientation = ['(100)', '(002)', '(101)', '(102)', '(110)', '(103)', '(200)', '(112)', '(201)', '(004)', '(202)']

plt.xlim([30, 80])
plt.yscale('log')

plt.xlabel('2θ Angle')
plt.ylabel('Intensity')

for position in peak_list:
    plt.axvline(x=position, color='red', linestyle='--', label=f'X={position}')
    orient = peak_list.index(position)
    plt.text(position, 0.8, f'{peak_orientation[orient]}', color='black', fontsize=7, ha='center', bbox=dict(facecolor='white', edgecolor='black', boxstyle='square,pad=0.2'))

plt.grid(True) 
plt.plot(x,y,linewidth=0.5)

# %%
import pandas as pd
from matplotlib import pyplot as plt
import plotly.express as px

plt.figure(figsize=(10,3))

df = pd.read_csv('ZnO_Task1.csv', skiprows=21)
x = df['Angle']
y = df['Intensity']

peak_list = [81.405, 89.63, 92.777, 95.311, 98.632, 102.923, 104.169, 107.448, 110.378, 116.288, 121.562, 125.234]
peak_orientation = ['(104)', '(203)', '(210)', '(211)', '(114)', '(212)', '(105)', '(204)', '(300)', '(213)', '(302)', '(006)']

plt.xlim([80, 130])
plt.yscale('log')

plt.xlabel('2θ Angle')
plt.ylabel('Intensity')

for position in peak_list:
    plt.axvline(x=position, color='red', linestyle='--', label=f'X={position}')
    orient = peak_list.index(position)
    plt.text(position, 0.8, f'{peak_orientation[orient]}', color='black', fontsize=7, ha='center', bbox=dict(facecolor='white', edgecolor='black', boxstyle='square,pad=0.2'))

plt.grid(True) 
plt.plot(x,y,linewidth=0.5)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
