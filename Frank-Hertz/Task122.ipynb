# %%
import numpy as np
import matplotlib.pyplot as plt


data = np.loadtxt('2024-05-07-task122-txtfile.txt')
#strongHg_list = np.loadtxt('Strong_lines_Hg.txt', dtype=int)

with open('Strong_lines_Hg.txt', 'r') as file:
    lines = file.readlines()

strongline_Hg = []
for line in lines:
    # Process each line (e.g., remove newline character)
    cleaned_line = line.strip()
    # Append the cleaned line to your array
    strongline_Hg.append(cleaned_line)

x = data[:, 0]  
y = data[:, 1] 

new_lines_list = [float(item) for item in strongline_Hg]

Hg_spectral_lines_x = [253.62, 296.49, 365.08, 404.78, 435.95, 546.25]
artifact_lines = [312.86, 578.79]

plt.figure(figsize=(12.5, 5), dpi=100)

#indices = np.searchsorted(x, strongline_Hg)
#strongline_Hg_y = y[indices]

for position in new_lines_list:
    plt.axvline(x=position, color='red', linestyle='--')
    plt.text(position, 1e5, f'{position}', color='black', fontsize=8, ha='left', rotation=45, bbox=dict(facecolor='white', edgecolor='black', boxstyle='square,pad=0.2'))

plt.xlabel('Wavelenght (nm)')
plt.ylabel('Intencity (a.u.)')
plt.xlim(178.80,886.38)
plt.ylim(1e2,1e5)


#for position in Hg_spectral_lines_x:
    #plt.axvline(x=position, color='red', linestyle='--', label=f'X={position}')
    #plt.text(position, 0.5, f'{position}', color='black', fontsize=8, ha='center', bbox=dict(facecolor='white', edgecolor='black', boxstyle='square,pad=0.2'))

#for position in artifact_lines:
    #plt.axvline(x=position, color='green', linestyle='--', label=f'X={position}')
    #plt.text(position, 0.5, f'{position}', color='green', fontsize=8, ha='left', bbox=dict(facecolor='white', edgecolor='black', boxstyle='square,pad=0.2'))

#print("Extracted y-values:", Hg_spectral_lines_y)

print("Strong Hg spectral lines:", strongline_Hg)
plt.grid(True)
plt.semilogy(x, y-1300, label='Measured Spectrum')
plt.legend(loc="upper right")
# Out:
# Strong Hg spectral lines: ['202.6860', '226.3634', '253.6517', '265.2039', '296.7280', '302.1498', '312.5668', '320.8169', '353.2594', '365.4836', '404.6563', '435.8328', '512.8442', '520.4768', '546.0735', '567.7105', '579.00663', '588.8939', '614.6435', '708.190', '734.6508', '794.4555']

# %%
import numpy as np
import matplotlib.pyplot as plt


data = np.loadtxt('2024-05-07-task122-txtfile.txt')
#strongHg_list = np.loadtxt('Strong_lines_Hg.txt', dtype=int)

with open('Term_diag_values.txt', 'r') as file:
    lines = file.readlines()

strongline_Hg = []
for line in lines:
    # Process each line (e.g., remove newline character)
    cleaned_line = line.strip()
    # Append the cleaned line to your array
    strongline_Hg.append(cleaned_line)

x = data[:, 0]  
y = data[:, 1] 

new_lines_list = [float(item) for item in strongline_Hg]

Hg_spectral_lines_x = [253.62, 296.49, 365.08, 404.78, 435.95, 546.25]
artifact_lines = [312.86, 578.79]

plt.figure(figsize=(12.5, 5), dpi=100)

#indices = np.searchsorted(x, strongline_Hg)
#strongline_Hg_y = y[indices]

for position in new_lines_list:
    plt.axvline(x=position, color='red', linestyle='--')
    plt.text(position, 1e5, f'{position}', color='black', fontsize=8, ha='left', rotation=45, bbox=dict(facecolor='white', edgecolor='black', boxstyle='square,pad=0.2'))

plt.xlabel('Wavelenght (nm)')
plt.ylabel('Intencity (a.u.)')
plt.xlim(178.80,600)
plt.ylim(1e2,1e5)


#for position in Hg_spectral_lines_x:
    #plt.axvline(x=position, color='red', linestyle='--', label=f'X={position}')
    #plt.text(position, 0.5, f'{position}', color='black', fontsize=8, ha='center', bbox=dict(facecolor='white', edgecolor='black', boxstyle='square,pad=0.2'))

#for position in artifact_lines:
    #plt.axvline(x=position, color='green', linestyle='--', label=f'X={position}')
    #plt.text(position, 0.5, f'{position}', color='green', fontsize=8, ha='left', bbox=dict(facecolor='white', edgecolor='black', boxstyle='square,pad=0.2'))

#print("Extracted y-values:", Hg_spectral_lines_y)

print("Strong Hg spectral lines:", strongline_Hg)
plt.grid(True)
plt.semilogy(x, y-1300, label='Measured Spectrum')
plt.legend(loc="upper right")
# Out:
# Strong Hg spectral lines: ['185', '253.6', '296.7', '312.6', '313.2', '366.3', '365.5', '365', '435.8', '404.7', '546.1', '577', '491.6', '410.8', '434.8', '579']
